# %% [markdown]
# # 🩺 Mission: Dr. AI and the Healthcare Conquest
#
# **Introduction:**
#
# Listen up, data scientists! Today, you’ve got a job that’s a little… unconventional. You’re taking on the role of Dr Robot House "doctor" who knows nothing about actual patients and cannot understand this data. Your challenge? To slice, dice, and understand a set of imaginary patient records and finally make sense of the chaotic world of healthcare data. No pressure—just all eyes on you to deliver some groundbreaking insights!
#
# Inside this synthetic healthcare dataset, you’ll find everything from admissions and medications to test results. Your task: sort through the data, clean it up, and pull out meaningful patterns. Do you have what it takes to go from data scientist to "doctor" (well, sort of) and show this dataset who’s boss? Let’s find out!
#
#
#
# ![](https://github.com/samsung-ai-course/6-7-edition/blob/main/Data%20Wrangling/Data%20Wrangling%20-%20Hackthon/media/dr_robot_house.png?raw=1)
#
# ---
# # 📊 About the Dataset
#
#
# **Dataset Overview:**
# This dataset mimics actual healthcare records, generated using Python’s Faker library to provide realistic yet completely synthetic patient data. Here’s a quick breakdown of the dataset:
#
#   - **Name:** Patient name.
#
#   - **Age:** Patient's age at admission.
#   - **Gender:** Patient's gender.
#   - **Blood Type:** Blood type (e.g., "A+", "O-").
#   - **Medical Condition:** Primary diagnosis, e.g., "Diabetes," "Hypertension."
#   - **Date of Admission:** Date when the patient was admitted.
#   - **Doctor:** The doctor responsible for the patient.
#   - **Hospital:** Hospital where the patient was admitted.
#   - **Insurance Provider:** Insurance provider, e.g., "Aetna," "Medicare."
#   - **Billing Amount:** Amount billed for healthcare services.
#   - **Room Number:** Patient's room during admission.
#   - **Admission Type:** Type of admission, e.g., "Emergency."
#   - **Discharge Date:** Date the patient was discharged.
#   - **Medication:** Medication prescribed to the patient.
#   - **Test Results:** Outcome of a medical test (e.g., "Normal," "Abnormal").
#
# ---
#
# # 📅 Timeline of Tasks
#
# Below is a suggested timeline for you to work through the dataset, explore its contents, and create insights:
#
# 1. **Load the dataset files into a Pandas DataFrame** (17:45 - 18:00)
#
# 3. **Understand the data** - Explore each column, NaNs, identify patterns (18:00 - 18:15)
# 4. **Calculate univariate statistics and create graphs** - Highlight statistics that could reveal trends or patterns using only one variable (18:15 - 18:40)
# 5. **Create multivariate statistics and graphs** - Use various plots (e.g., lineplots, barplots, scatter plots) to present data relationships (18:40 - 19:20)
# 6. **Prepare notebook for presentation** - (19:20 - 19:30)
# 7. **Organize presentation** - Organize how you gonna present your findings (19:30-19:40)
# 8. **Organize presentation** - Presentation start (19:45)

# %% [markdown]
# ![](https://github.com/samsung-ai-course/6-7-edition/blob/main/Data%20Wrangling/media/dr_robot_house.png?raw=1)

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/samsung-ai-course/6-7-edition/refs/heads/main/Data%20Wrangling/Data%20Wrangling%20-%20Hackthon/dataset/healthcare_dataset.csv"
df = pd.read_csv(url)
#df= pd.read_csv('dataset/healthcare_dataset.csv')

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/samsung-ai-course/6-7-edition/refs/heads/main/Data%20Wrangling/Data%20Wrangling%20-%20Hackthon/dataset/healthcare_dataset.csv"
df = pd.read_csv(url)

# %%
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [16, 4]

# %%
plt.hist(df['Age'], bins=40, edgecolor='black')
plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting billing amount distribution
plt.figure(figsize=(10, 6))
plt.hist(df['Billing Amount'], bins=30, edgecolor='black')
plt.title('Billing Amount Distribution')
plt.xlabel('Billing Amount')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting Admission Type counts
plt.figure(figsize=(10, 6))
df['Admission Type'].value_counts().plot(kind='bar', edgecolor='black')
plt.title('Admission Type Counts')
plt.xlabel('Admission Type')
plt.ylabel('Frequency')
plt.ylim(17000, 19000)  # Setting the y-axis range to improve visibility of differences

plt.show()

# %%
# Calculating the average billing amount for each admission type
billing_by_admission_type = df.groupby('Admission Type')['Billing Amount'].mean()

# Plotting the average billing amount for each admission type
plt.figure(figsize=(10, 6))
billing_by_admission_type.plot(kind='bar', edgecolor='black')
plt.title('Average Billing Amount by Admission Type')
plt.xlabel('Admission Type')
plt.ylabel('Average Billing Amount')
plt.ylim(25000, 26000)  # Setting the y-axis range to improve visibility of differences
plt.show()

# %%
billing_by_admission_type
# Out:
# Admission Type
# Elective     25602.226311
# Emergency    25497.397157
# Urgent       25517.364497
# Name: Billing Amount, dtype: float64

# %%
plt.figure(figsize=(10, 6))
billing_by_admission_type.plot(kind='bar', edgecolor='black')
plt.title('Average Billing Amount by Admission Type')
plt.xlabel('Admission Type')
plt.ylabel('Average Billing Amount')
plt.ylim(25000, 26000)  # Setting the y-axis range to improve visibility of differences
plt.show()

# %%
# Calculating the average billing amount for each medical condition
billing_by_medical_condition = df.groupby('Medical Condition')['Billing Amount'].mean().sort_values(ascending=False)

# Plotting the average billing amount for each medical condition (showing top 10 for readability)
plt.figure(figsize=(12, 8))
billing_by_medical_condition.head(10).plot(kind='bar', edgecolor='black')
plt.title('Medical Conditions by Average Billing Amount')
plt.xlabel('Medical Condition')
plt.ylabel('Average Billing Amount')
plt.ylim(25000, 26000)  # Setting the y-axis range to improve visibility of differences
plt.show()

# %%
billing_by_medical_condition
# Out:
# Medical Condition
# Obesity         25805.971259
# Diabetes        25638.405577
# Asthma          25635.249359
# Arthritis       25497.327056
# Hypertension    25497.095761
# Cancer          25161.792707
# Name: Billing Amount, dtype: float64

# %%
# Out:
# Correlation between average billing amount and medical condition: nan

# %%
# Plotting a scatter plot to visualize the trend between Age and Billing Amount
plt.figure(figsize=(12, 8))
plt.scatter(df['Age'], df['Billing Amount'], alpha=0.3)
plt.title('Billing Amount vs Age')
plt.xlabel('Age')
plt.ylabel('Billing Amount')
plt.show()

# %%
# Calculating the correlation between Age and Billing Amount to quantify the trend
age_billing_corr = df[['Age', 'Billing Amount']].corr().iloc[0, 1]
print("Correlation between Age and Billing Amount:", age_billing_corr)
# Out:
# Correlation between Age and Billing Amount: -0.0038319421186176848

# %%
# Converting admission and discharge dates to datetime format if not already done
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'])
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'])

# Calculating length of stay as the difference in days between admission and discharge
df['Length of Stay'] = (df['Discharge Date'] - df['Date of Admission']).dt.days

# %%
# Calculating the average length of stay for each medical condition
avg_length_of_stay_by_condition = df.groupby('Medical Condition')['Length of Stay'].mean().sort_values(ascending=False)
avg_length_of_stay_by_condition
# Out:
# Medical Condition
# Asthma          15.696570
# Arthritis       15.517404
# Cancer          15.495827
# Obesity         15.464305
# Hypertension    15.458626
# Diabetes        15.422936
# Name: Length of Stay, dtype: float64

# %%
# Displaying the top 10 medical conditions by average length of stay for better readability
plt.figure(figsize=(12, 8))
avg_length_of_stay_by_condition.head(10).plot(kind='bar', edgecolor='black')
plt.title('Medical Conditions by Average Length of Stay')
plt.xlabel('Medical Condition')
plt.ylabel('Average Length of Stay (Days)')
plt.ylim(14, 16)  # Setting the y-axis range to improve visibility of differences
plt.show()

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
X = df[['Age', 'Blood Type', 'Admission Type', 'Medical Condition']]
y = df['Length of Stay']

X = pd.get_dummies(X, columns=['Blood Type', 'Admission Type', 'Medical Condition'], drop_first=True)


model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)
y_pred[:3]
# Out:
# array([15.336254  , 15.56339812, 15.58068684])

# %%
errors = np.mean(np.abs(y- y_pred))
errors
# Out:
# 1.8776077768206176

# %%
# Out:
# -8.557918032911704e-15

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# Filter for cancer cases
cancer_df = df[df['Medical Condition'] == 'Cancer']

# Convert the admission date to datetime
cancer_df['Date of Admission'] = pd.to_datetime(cancer_df['Date of Admission'])

# Count the number of cancer cases per day
cancer_cases_per_day = cancer_df['Date of Admission'].value_counts().sort_index()

# Prepare the data for regression
X = cancer_cases_per_day.index.map(lambda date: date.toordinal()).values.reshape(-1, 1)
y = cancer_cases_per_day.values

# Initialize and fit the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions on the training data for plotting
y_pred = model.predict(X)

# Plotting the actual cancer cases and the regression line
plt.figure(figsize=(12, 6))
plt.plot(cancer_cases_per_day.index, y, label='Actual Cancer Cases')
plt.plot(cancer_cases_per_day.index, y_pred, color='red', linestyle='--', label='Trend Line (Linear Regression)')
plt.title('Cancer Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Cancer Cases')
plt.legend()
plt.show()
# Out:
# <ipython-input-47-b39886b1a1e2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cancer_df['Date of Admission'] = pd.to_datetime(cancer_df['Date of Admission'])

# %%
y - y_pred
# Out:
# array([ 6.73945876, -3.26036281, -0.26018438, ..., -0.9350856 ,
#        -2.93490717,  0.06527126])

# %%
import numpy as np

# %%
np.mean(y - y_pred)
# Out:
# -8.557918032911704e-15
