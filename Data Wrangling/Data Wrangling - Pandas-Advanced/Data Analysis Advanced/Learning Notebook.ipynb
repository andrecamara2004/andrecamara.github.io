# %% [markdown]
# # What this notebook teaches
#
# 1. Advanced `Masking`: combining multiple masks
# 2. `Apply` operation: for **transforming** columns and **creating** new ones
# 3. `Groupby` operation
# 4. More `plotting` functionalities

# %% [markdown]
# # Options

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the data

# %%
url = 'https://raw.githubusercontent.com/samsung-ai-course/6-7-edition/refs/heads/main/Data%20Wrangling/Data%20Wrangling%20-%20Pandas-Advanced/Data%20Analysis%20Advanced/data/global-data-on-sustainable-energy.csv'

df = pd.read_csv(url)
df.head(3)
df.shape
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
#
#    Financial flows to developing countries (US $)  \
# 0                                         20000.0
# 1                                        130000.0
# 2                                       3950000.0
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                              44.99
# 1                                              45.60
# 2                                              37.83
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                 0.16                             0.0
# 1                                 0.09                             0.0
# 2                                 0.13                             0.0
#
#    Electricity from renewables (TWh)  ...  \
# 0                               0.31  ...
# 1                               0.50  ...
# 2                               0.56  ...
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                          302.59482
# 1                                          236.89185
# 2                                          210.86215
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                               1.64
# 1                                               1.74
# 2                                               1.40
#
#    Value_co2_emissions_kt_by_country  \
# 0                         760.000000
# 1                         730.000000
# 2                        1029.999971
#
#    Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 0                                       NaN         NaN             NaN
# 1                                       NaN         NaN             NaN
# 2                                       NaN         NaN      179.426579
#
#    Density\n(P/Km2) Land Area(Km2)  Latitude  Longitude
# 0                60       652230.0  33.93911  67.709953
# 1                60       652230.0  33.93911  67.709953
# 2                60       652230.0  33.93911  67.709953
#
# [3 rows x 21 columns]
# (3649, 21)

# %% [markdown]
# # Advanced Masking

# %% [markdown]
# ![](https://github.com/samsung-ai-course/6-7-edition/blob/main/Data%20Wrangling/Data%20Wrangling%20-%20Pandas-Advanced/Data%20Analysis%20Advanced/media/dino.jpeg?raw=1)

# %% [markdown]
# ## Using `&` (AND) operator

# %% [markdown]
# Let's say i want:
# 1. `United States`
# 2. from `2012`

# %%
mask_us = df['Entity'] == 'United States'
mask_2012 = df['Year'] == 2012

# %%
mask_us & mask_2012
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3644    False
# 3645    False
# 3646    False
# 3647    False
# 3648    False
# Length: 3649, dtype: bool

# %%
df.loc[mask_us & mask_2012]
# Out:
#              Entity  Year  Access to electricity (% of population)  \
# 3514  United States  2012                                    100.0
#
#       Access to clean fuels for cooking  \
# 3514                              100.0
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 3514                                                NaN
#
#       Financial flows to developing countries (US $)  \
# 3514                                             NaN
#
#       Renewable energy share in the total final energy consumption (%)  \
# 3514                                               8.73
#
#       Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 3514                              2779.02                          769.33
#
#       Electricity from renewables (TWh)  ...  \
# 3514                             492.32  ...
#
#       Primary energy consumption per capita (kWh/person)  \
# 3514                                           79102.34
#
#       Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 3514                                               5.15
#
#       Value_co2_emissions_kt_by_country  \
# 3514                        4956060.059
#
#       Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 3514                                  6.886334    2.249546     51602.93105
#
#       Density\n(P/Km2) Land Area(Km2)  Latitude  Longitude
# 3514                36      9833517.0  37.09024 -95.712891
#
# [1 rows x 21 columns]

# %% [markdown]
# And if i now want all countries where:
# 1. In the year `2018`
# 2. had `gdp_growth` of at least 7.5

# %%
mask_2018 = df['Year'] == 2018
mask_gdp_growth = df['gdp_growth'] > 7.5

# %%
df.loc[mask_gdp_growth & mask_2018,:]
# Out:
#           Entity  Year  Access to electricity (% of population)  \
# 291   Bangladesh  2018                                91.800000
# 942     Djibouti  2018                                60.564186
# 1615     Ireland  2018                               100.000000
# 1930       Libya  2018                                67.000000
# 2056    Maldives  2018                               100.000000
# 2182    Mongolia  2018                                98.100000
# 2322       Nepal  2018                                93.920000
# 2763      Rwanda  2018                                36.968150
# 3071     Somalia  2018                                50.764977
# 3247  Tajikistan  2018                                99.300000
#
#       Access to clean fuels for cooking  \
# 291                                21.9
# 942                                 9.3
# 1615                              100.0
# 1930                                NaN
# 2056                               98.8
# 2182                               48.7
# 2322                               32.3
# 2763                                1.4
# 3071                                2.7
# 3247                               80.9
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 291                                                2.72
# 942                                                0.38
# 1615                                                NaN
# 1930                                               0.76
# 2056                                              21.21
# 2182                                              79.31
# 2322                                              39.61
# 2763                                              10.61
# 3071                                               0.71
# 3247                                             566.26
#
#       Financial flows to developing countries (US $)  \
# 291                                      235500000.0
# 942                                       30470000.0
# 1615                                             NaN
# 1930                                             NaN
# 2056                                       5690000.0
# 2182                                     116030000.0
# 2322                                      14870000.0
# 2763                                      15840000.0
# 3071                                       3210000.0
# 3247                                             NaN
#
#       Renewable energy share in the total final energy consumption (%)  \
# 291                                               26.88
# 942                                               27.84
# 1615                                              10.78
# 1930                                               2.75
# 2056                                               1.12
# 2182                                               3.26
# 2322                                              74.27
# 2763                                              84.50
# 3071                                              94.93
# 3247                                              39.47
#
#       Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 291                                 72.56                             0.0
# 942                                  0.05                             0.0
# 1615                                20.70                             0.0
# 1930                                32.11                             0.0
# 2056                                 0.61                             0.0
# 2182                                 5.71                             0.0
# 2322                                 0.00                             0.0
# 2763                                 0.49                             0.0
# 3071                                 0.33                             0.0
# 3247                                 1.27                             0.0
#
#       Electricity from renewables (TWh)  ...  \
# 291                                1.40  ...
# 942                                0.00  ...
# 1615                              10.20  ...
# 1930                               0.01  ...
# 2056                               0.03  ...
# 2182                               0.44  ...
# 2322                               4.99  ...
# 2763                               0.37  ...
# 3071                               0.02  ...
# 3247                              18.21  ...
#
#       Primary energy consumption per capita (kWh/person)  \
# 291                                          2630.02780
# 942                                          3133.48050
# 1615                                        38573.79700
# 1930                                        31662.73600
# 2056                                        17020.91000
# 2182                                        22486.17200
# 2322                                         1753.60060
# 2763                                          491.12625
# 3071                                          236.28375
# 3247                                         7761.81640
#
#       Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 291                                                2.30
# 942                                                2.02
# 1615                                               1.41
# 1930                                               7.16
# 2056                                               2.56
# 2182                                               6.37
# 2322                                               5.68
# 2763                                               4.01
# 3071                                              11.69
# 3247                                               4.73
#
#       Value_co2_emissions_kt_by_country  \
# 291                        83449.996950
# 942                          400.000006
# 1615                       37659.999850
# 1930                       56619.998930
# 2056                        2099.999905
# 2182                       21549.999240
# 2322                       15189.999580
# 2763                        1289.999962
# 3071                         660.000026
# 3247                        8680.000305
#
#       Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 291                                   0.747117    7.863754     1698.132081
# 942                                        NaN    8.407663     3141.861711
# 1615                                 14.717063    9.030161    79068.974610
# 1930                                       NaN   15.132800     7877.124610
# 2056                                       NaN    8.123129    10279.079980
# 2182                                       NaN    7.744881     4156.846970
# 2322                                       NaN    7.622376     1178.525932
# 2763                                       NaN    8.579425      783.637163
# 3071                                       NaN    7.678880      389.831395
# 3247                                       NaN    7.599999      853.218873
#
#       Density\n(P/Km2) Land Area(Km2)   Latitude   Longitude
# 291              1,265       148460.0  23.684994   90.356331
# 942                 43        23200.0  11.825138   42.590275
# 1615                73        84421.0  53.412910   -8.243890
# 1930                 4      1759540.0  26.335100   17.228331
# 2056             1,802          298.0   3.202778   73.220680
# 2182                 2      1564116.0  46.862496  103.846656
# 2322               203       147181.0  28.394857   84.124008
# 2763               525        26338.0  -1.940278   29.873888
# 3071                25       637657.0   5.152149   46.199616
# 3247                68       144100.0  38.861034   71.276093
#
# [10 rows x 21 columns]

# %% [markdown]
# If we just want the list:

# %%
df.loc[mask_gdp_growth & mask_2018,'Entity'].tolist()
# Out:
# ['Bangladesh',
#  'Djibouti',
#  'Ireland',
#  'Libya',
#  'Maldives',
#  'Mongolia',
#  'Nepal',
#  'Rwanda',
#  'Somalia',
#  'Tajikistan']

# %% [markdown]
# And all the countries whose gdp went down in 2018?

# %%
mask_2018 = df['Year'] == 2018
mask_negative_gdp_growth = df['gdp_growth'] < 0

df.loc[mask_negative_gdp_growth & mask_2018,'Entity'].tolist()
# Out:
# ['Angola',
#  'Argentina',
#  'Barbados',
#  'Bermuda',
#  'Equatorial Guinea',
#  'Lebanon',
#  'Lesotho',
#  'Nicaragua',
#  'Papua New Guinea',
#  'Puerto Rico',
#  'Samoa',
#  'Sudan']

# %% [markdown]
# ## Using `|` (OR) operator

# %% [markdown]
# I want all data from both:
# 1. `Albania`
# 2. and `Angola`

# %%
mask_albania = df['Entity'] == 'Albania'
mask_angola = df['Entity'] == 'Angola'

# %%
df.loc[mask_albania | mask_angola,:].head(3) # remove the .head to confirm the results
# Out:
#      Entity  Year  Access to electricity (% of population)  \
# 21  Albania  2000                                    100.0
# 22  Albania  2001                                    100.0
# 23  Albania  2002                                    100.0
#
#     Access to clean fuels for cooking  \
# 21                               38.2
# 22                               40.5
# 23                               43.2
#
#     Renewable-electricity-generating-capacity-per-capita  \
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#     Financial flows to developing countries (US $)  \
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
#
#     Renewable energy share in the total final energy consumption (%)  \
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#     Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 21                                 0.14                             0.0
# 22                                 0.13                             0.0
# 23                                 0.16                             0.0
#
#     Electricity from renewables (TWh)  ...  \
# 21                               4.55  ...
# 22                               3.52  ...
# 23                               3.48  ...
#
#     Primary energy consumption per capita (kWh/person)  \
# 21                                          9029.4375
# 22                                          8635.5320
# 23                                          9443.5550
#
#     Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 21                                               4.13
# 22                                               3.89
# 23                                               4.10
#
#     Value_co2_emissions_kt_by_country  \
# 21                         3170.00000
# 22                         3230.00000
# 23                         3759.99999
#
#     Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 21                                       NaN    6.946217     1126.683340
# 22                                       NaN    8.293313     1281.659826
# 23                                       NaN    4.536524     1425.124219
#
#     Density\n(P/Km2) Land Area(Km2)   Latitude  Longitude
# 21               105        28748.0  41.153332  20.168331
# 22               105        28748.0  41.153332  20.168331
# 23               105        28748.0  41.153332  20.168331
#
# [3 rows x 21 columns]

# %% [markdown]
# Pretty cool! However, we don't have to stick to conditions on the same columns:

# %% [markdown]
# For `2020`, I want the countries where `either`:
# 1. The `GDP` grew by at least 4.0
# 2. The `Primary energy consumption per capita` was above 1050

# %%
mask_2020 = df['Year'] == 2020
mask_gdp = df['gdp_growth'] > 4.0
mask_energy_consumption = df['Primary energy consumption per capita (kWh/person)'] > 1050

# %%
df.loc[mask_2020 & (mask_gdp | mask_energy_consumption)]
# Out:
#                    Entity  Year  Access to electricity (% of population)  \
# 41                Albania  2020                               100.000000
# 62                Algeria  2020                                99.804130
# 83                 Angola  2020                                46.890610
# 104   Antigua and Barbuda  2020                               100.000000
# 125             Argentina  2020                               100.000000
# ...                   ...   ...                                      ...
# 3564           Uzbekistan  2020                               100.000000
# 3585              Vanuatu  2020                                67.333270
# 3606                Yemen  2020                                73.757930
# 3627               Zambia  2020                                44.524475
# 3648             Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 41                                81.30
# 62                                99.70
# 83                                50.20
# 104                              100.00
# 125                               99.90
# ...                                 ...
# 3564                              84.25
# 3585                               7.60
# 3606                              61.50
# 3627                              10.40
# 3648                              30.40
#
#       Renewable-electricity-generating-capacity-per-capita  \
# 41                                                  NaN
# 62                                                15.64
# 83                                               115.43
# 104                                              167.98
# 125                                              311.28
# ...                                                 ...
# 3564                                              60.02
# 3585                                              37.84
# 3606                                               8.48
# 3627                                             138.23
# 3648                                              80.61
#
#       Financial flows to developing countries (US $)  \
# 41                                               NaN
# 62                                               NaN
# 83                                               NaN
# 104                                              NaN
# 125                                              NaN
# ...                                              ...
# 3564                                             NaN
# 3585                                             NaN
# 3606                                             NaN
# 3627                                             NaN
# 3648                                         30000.0
#
#       Renewable energy share in the total final energy consumption (%)  \
# 41                                                  NaN
# 62                                                  NaN
# 83                                                  NaN
# 104                                                 NaN
# 125                                                 NaN
# ...                                                 ...
# 3564                                                NaN
# 3585                                                NaN
# 3606                                                NaN
# 3627                                                NaN
# 3648                                               81.9
#
#       Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 41                                   0.00                            0.00
# 62                                  72.01                            0.00
# 83                                   4.49                            0.00
# 104                                  0.31                            0.00
# 125                                 91.58                           10.06
# ...                                   ...                             ...
# 3564                                50.93                            0.00
# 3585                                 0.05                            0.00
# 3606                                 2.74                            0.00
# 3627                                 2.00                            0.00
# 3648                                 3.40                            0.00
#
#       Electricity from renewables (TWh)  ...  \
# 41                                 5.31  ...
# 62                                 0.72  ...
# 83                                12.10  ...
# 104                                0.02  ...
# 125                               37.05  ...
# ...                                 ...  ...
# 3564                               5.01  ...
# 3585                               0.02  ...
# 3606                               0.49  ...
# 3627                              13.10  ...
# 3648                               4.19  ...
#
#       Primary energy consumption per capita (kWh/person)  \
# 41                                           11158.0030
# 62                                           14933.8070
# 83                                            3527.1600
# 104                                          27785.2270
# 125                                          19314.0660
# ...                                                 ...
# 3564                                         15860.6090
# 3585                                          2923.5380
# 3606                                          1092.0021
# 3627                                          3099.0830
# 3648                                          2680.1318
#
#       Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 41                                                  NaN
# 62                                                  NaN
# 83                                                  NaN
# 104                                                 NaN
# 125                                                 NaN
# ...                                                 ...
# 3564                                                NaN
# 3585                                                NaN
# 3606                                                NaN
# 3627                                                NaN
# 3648                                               10.0
#
#       Value_co2_emissions_kt_by_country  \
# 41                                  NaN
# 62                                  NaN
# 83                                  NaN
# 104                                 NaN
# 125                                 NaN
# ...                                 ...
# 3564                                NaN
# 3585                                NaN
# 3606                                NaN
# 3627                                NaN
# 3648                                NaN
#
#       Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 41                                         NaN   -3.955398     5246.292306
# 62                                    0.297899   -5.100000     3306.858208
# 83                                         NaN   -5.399987     1776.166868
# 104                                        NaN  -20.192371    13992.744480
# 125                                  12.179417   -9.895269     8579.017773
# ...                                        ...         ...             ...
# 3564                                  2.523421    1.714771     1750.697113
# 3585                                       NaN   -6.813991     2870.089300
# 3606                                       NaN         NaN             NaN
# 3627                                       NaN   -2.785055      985.132436
# 3648                                       NaN   -6.248748     1214.509820
#
#       Density\n(P/Km2) Land Area(Km2)   Latitude   Longitude
# 41                 105        28748.0  41.153332   20.168331
# 62                  18      2381741.0  28.033886    1.659626
# 83                  26      1246700.0 -11.202692   17.873887
# 104                223          443.0  17.060816  -61.796428
# 125                 17      2780400.0 -38.416097  -63.616672
# ...                ...            ...        ...         ...
# 3564                79       447400.0  41.377491   64.585262
# 3585                25        12189.0 -15.376706  166.959158
# 3606                56       527968.0  15.552727   48.516388
# 3627                25       752618.0 -13.133897   27.849332
# 3648                38       390757.0 -19.015438   29.154857
#
# [157 rows x 21 columns]

# %% [markdown]
# Very cool! Now i can compute any analysis for this data

# %%
# what is the distribution of land area density of these countries?

df.loc[mask_2020 & (mask_gdp | mask_energy_consumption),'Land Area(Km2)'].describe().astype(int)
# Out:
# count        157
# mean      660309
# std      1665289
# min           21
# 25%        21041
# 50%       112090
# 75%       488100
# max      9984670
# Name: Land Area(Km2), dtype: int64

# %%
# What is the average `Financial aid to developing countries` of these countries in 2020, in thousands of $

df.loc[mask_2020 & (mask_gdp | mask_energy_consumption),'Financial flows to developing countries (US $)'].mean() / 1_000
# Out:
# 30.0

# %% [markdown]
# # `Apply` operation
#
# Let's go back to the supermarket sales

# %%
url = 'https://raw.githubusercontent.com/samsung-ai-course/6-7-edition/refs/heads/main/Data%20Wrangling/Data%20Wrangling%20-%20Pandas-Advanced/Data%20Analysis%20Advanced/data/supermarket_sales.csv'
df = pd.read_csv(url)
df.head(3)
df.shape
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# (1000, 17)

# %%
a = 'dd/mm/yyy'
a.split('/')[0]
# Out:
# 'dd'

# %% [markdown]
# ## In strings
#
# `.apply` can be incredibly useful for string columns to help you parse and clean them for further analysis.
#
# For example, it would have been useful to use the Date column to at least analyze the data throughout time.
#
# We know that this dataset is only for the year 2019, so let's extract the month and day of the month so that we can use this information for further analysis

# %%
df['Date'].apply(lambda row: row.split('/')[0])
# Out:
# 0      1
# 1      3
# 2      3
# 3      1
# 4      2
#       ..
# 995    1
# 996    3
# 997    2
# 998    2
# 999    2
# Name: Date, Length: 1000, dtype: object

# %% [markdown]
# We applied a function to each row, which extracts the first string after splitting by the character `/` in order to get the month part of the date

# %%
#doing the same to extract the day
df['Date'].apply(lambda row: row.split('/')[1]) # day of the month
# Out:
# 0       5
# 1       8
# 2       3
# 3      27
# 4       8
#        ..
# 995    29
# 996     2
# 997     9
# 998    22
# 999    18
# Name: Date, Length: 1000, dtype: object

# %% [markdown]
# We can create new columns in our dataset with this info! Let's add this new data to our dataset

# %%
df['month'] = df['Date'].apply(lambda row: row.split('/')[0])
df['day'] = df['Date'].apply(lambda row: row.split('/')[1])
df['year'] = df['Date'].apply(lambda row: row.split('/')[2])

# %%
df.head(3)
df.shape
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
#
#   month day  year
# 0     1   5  2019
# 1     3   8  2019
# 2     3   3  2019
# (1000, 20)

# %% [markdown]
# Now that we have this extra information, we can do a lot more analysis to the data!

# %%
# how many sales in January?
mask_january = df['month'] == "1"

df.loc[mask_january,'Total'].sum()
# Out:
# 116291.86800000002

# %%
# what was the day of february with the largest purchase?
mask_february = df['month'] == "2"
index = df.loc[mask_february,'Total'].idxmax()

df.loc[index,'day']
# Out:
# '15'

# %%
# and the rest of the data for this day?
df.loc[index,:].to_frame('Value')
# Out:
#                                        Value
# Invoice ID                       860-79-0874
# Branch                                     C
# City                               Naypyitaw
# Customer type                         Member
# Gender                                Female
# Product line             Fashion accessories
# Unit price                              99.3
# Quantity                                  10
# Tax 5%                                 49.65
# Total                                1042.65
# Date                               2/15/2019
# Time                                   14:53
# Payment                          Credit card
# cogs                                   993.0
# gross margin percentage             4.761905
# gross income                           49.65
# Rating                                   6.6
# month                                      2
# day                                       15
# year                                    2019

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
#
#   month day  year
# 0     1   5  2019
# 1     3   8  2019
# 2     3   3  2019

# %% [markdown]
# ## In numerical data
#
# There are some columns that are computed through operations on other columns:
#
# For example:
#
# 1. `Tax 5%`: is simply `Unit price` * `Quantity` * 0.05
# 2. `Total`: is `Unit price` * `Quantity` + `Tax 5%`
#
#
# Let's do the `Tax 5%`

# %%
total_before_taxes = df['Unit price'] * df['Quantity']
total_before_taxes
# Out:
# 0      522.83
# 1       76.40
# 2      324.31
# 3      465.76
# 4      604.17
#         ...
# 995     40.35
# 996    973.80
# 997     31.84
# 998     65.82
# 999    618.38
# Length: 1000, dtype: float64

# %%
tax_5 = total_before_taxes.apply(lambda row: row * 0.05)
tax_5
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Length: 1000, dtype: float64

# %% [markdown]
# How do we compare our solution with the `Tax 5%` column? As always there are many ways to do that:

# %%
# visually
pd.concat([tax_5.rename('Ours'), df['Tax 5%']],axis=1)
# Out:
#         Ours   Tax 5%
# 0    26.1415  26.1415
# 1     3.8200   3.8200
# 2    16.2155  16.2155
# 3    23.2880  23.2880
# 4    30.2085  30.2085
# ..       ...      ...
# 995   2.0175   2.0175
# 996  48.6900  48.6900
# 997   1.5920   1.5920
# 998   3.2910   3.2910
# 999  30.9190  30.9190
#
# [1000 rows x 2 columns]

# %%
# numerically
(tax_5 - df['Tax 5%']).round(5).value_counts()
# Out:
# -0.0    1000
# Name: count, dtype: int64

# %% [markdown]
# Awesome! This confirms we did it well

# %% [markdown]
# > Let's say that now we want the `Total` in thousands of $

# %%
df.loc[:,'Total (thousands $)'] = df['Total'].apply(lambda row: row / 1000)

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3
#
#    month day  year Total (thousands $)
# 0      1   5  2019            0.548971
# 1      3   8  2019            0.080220
# 2      3   3  2019            0.340526
# 3      1  27  2019            0.489048
# 4      2   8  2019            0.634379
#
# [5 rows x 21 columns]

# %% [markdown]
# # Groupby
#
#
# [complete docs for groupby in Pandas](https://pandas.pydata.org/docs/reference/groupby.html)
#
#
# Often you want to compute information across all unique categories of a column.

# %%
url = 'https://raw.githubusercontent.com/samsung-ai-course/6-7-edition/refs/heads/main/Data%20Wrangling/Data%20Wrangling%20-%20Pandas-Advanced/Data%20Analysis%20Advanced/data/global-data-on-sustainable-energy.csv'

df = pd.read_csv(url)
df.head(3)
df.shape
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
#
#    Financial flows to developing countries (US $)  \
# 0                                         20000.0
# 1                                        130000.0
# 2                                       3950000.0
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                              44.99
# 1                                              45.60
# 2                                              37.83
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                 0.16                             0.0
# 1                                 0.09                             0.0
# 2                                 0.13                             0.0
#
#    Electricity from renewables (TWh)  ...  \
# 0                               0.31  ...
# 1                               0.50  ...
# 2                               0.56  ...
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                          302.59482
# 1                                          236.89185
# 2                                          210.86215
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                               1.64
# 1                                               1.74
# 2                                               1.40
#
#    Value_co2_emissions_kt_by_country  \
# 0                         760.000000
# 1                         730.000000
# 2                        1029.999971
#
#    Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 0                                       NaN         NaN             NaN
# 1                                       NaN         NaN             NaN
# 2                                       NaN         NaN      179.426579
#
#    Density\n(P/Km2) Land Area(Km2)  Latitude  Longitude
# 0                60       652230.0  33.93911  67.709953
# 1                60       652230.0  33.93911  67.709953
# 2                60       652230.0  33.93911  67.709953
#
# [3 rows x 21 columns]
# (3649, 21)

# %% [markdown]
# > What was the average gdp growth across **all countries** between `2015` and `2019`?

# %%
mask_years = (df['Year'] >= 2015) & (df['Year'] <= 2019)

(df
 .loc[mask_years,:] # select only data for the years between 2015 and 2019
 .groupby('Entity') # group by the countries
 ['gdp_growth'].mean() # get the average value of gdp_growth for each country
 .sort_values(ascending=False) # sort the result in descending order
)
# Out:
# Entity
# Ireland                             10.021132
# Ethiopia                             8.914074
# Somalia                              8.329505
# Bangladesh                           7.393346
# Guinea                               7.390242
#                                       ...
# Saint Kitts and Nevis                     NaN
# Saint Lucia                               NaN
# Saint Vincent and the Grenadines          NaN
# Slovakia                                  NaN
# Yemen                                     NaN
# Name: gdp_growth, Length: 175, dtype: float64

# %% [markdown]
# ## Plotting

# %% [markdown]
# pretty cool right? The results of groupby make some very good candidates for visualization

# %%
(df
 .loc[mask_years,:] # select only data for the years between 2015 and 2019
 .groupby('Entity') # group by the countries
 ['gdp_growth'].mean() # get the average value of gdp_growth for each country
 .sort_values(ascending=False) # sort the result in descending order
 .plot.bar()
)
# Out:
# <Axes: xlabel='Entity'>

# %% [markdown]
# ![](https://github.com/samsung-ai-course/6-7-edition/blob/main/Data%20Wrangling/Data%20Wrangling%20-%20Pandas-Advanced/Data%20Analysis%20Advanced/media/ugly.jpg?raw=1)

# %% [markdown]
# **Ouch** that hurts. There are so many countries in this dataset that they don't fit very well in the figure
#
# We can try a few things:
# 1. Increase the figure size
# 2. rotate the labels by 45 degrees
# 3. plot only the top 10

# %%
(df
 .loc[mask_years,:] # select only data for the years between 2015 and 2019
 .groupby('Entity') # group by the countries
 ['gdp_growth'].mean() # get the average value of gdp_growth for each country
 .sort_values(ascending=False) # sort the result in descending order
 .iloc[:10] # select top 10
 .plot.bar(rot=45,
           figsize=(16,8),
           title='Top 10 Countries by gdp growth between 2015 and 2019',
           ylabel='% gdp growth',
           xlabel='Country'
          )
)
# Out:
# <Axes: title={'center': 'Top 10 Countries by gdp growth between 2015 and 2019'}, xlabel='Country', ylabel='% gdp growth'>

# %% [markdown]
# Much better! Font size for the labels and title are a bit small though, let's increase them

# %%
ax = (df
     .loc[mask_years,:] # select only data for the years between 2015 and 2019
     .groupby('Entity') # group by the countries
     ['gdp_growth'].mean() # get the average value of gdp_growth for each country
     .sort_values(ascending=False) # sort the result in descending order
     .iloc[:10] # select top 10
     .plot.bar(rot=45,
               figsize=(16,8)
              )
    )

ax.set_xlabel('Country', fontsize=20);
ax.set_ylabel('% gdp growth', fontsize=20);
ax.set_title('Top 10 Countries by gdp growth between 2015 and 2019', fontsize=20);

# %% [markdown]
# ## Continuing Groupby
#
# Groupby is a very powerful tool, let's analyze more use cases we can do with it

# %% [markdown]
# > What is the average gdp growth by year of our list of countries?

# %%
df.groupby('Year')['gdp_growth'].mean()
# Out:
# Year
# 2000    4.300344
# 2001    3.365428
# 2002    3.414374
# 2003    4.039049
# 2004    5.911710
# 2005    5.158672
# 2006    6.126791
# 2007    5.792441
# 2008    4.000764
# 2009   -0.016608
# 2010    4.301192
# 2011    3.868634
# 2012    4.142701
# 2013    3.445341
# 2014    3.371002
# 2015    2.999501
# 2016    3.102784
# 2017    3.408944
# 2018    3.363001
# 2019    2.866852
# 2020   -4.532741
# Name: gdp_growth, dtype: float64

# %% [markdown]
# > In total, how much did each country financially aid developing countries? (in billions of \$)

# %%
df.groupby('Entity')['Financial flows to developing countries (US $)'].sum().sort_values(ascending=False) / 1_000_000_000
# Out:
# Entity
# India             13.64066
# Pakistan           9.38093
# Nigeria            7.63776
# Ethiopia           7.08098
# Turkey             6.85095
#                     ...
# Netherlands        0.00000
# Cayman Islands     0.00000
# Montenegro         0.00000
# Croatia            0.00000
# Latvia             0.00000
# Name: Financial flows to developing countries (US $), Length: 176, dtype: float64

# %% [markdown]
# again, we can make a visualization out of this

# %%
result = df.groupby('Entity')['Financial flows to developing countries (US $)'].sum().sort_values(ascending=False) / 1_000_000_000

result.head(10).plot.bar(title='Top countries with most financial aid to developing countries between 2000 and 2020',rot=45,xlabel='Country',ylabel='$ (billions)')
# Out:
# <Axes: title={'center': 'Top countries with most financial aid to developing countries between 2000 and 2020'}, xlabel='Country', ylabel='$ (billions)'>

# %% [markdown]
# > What was the worst GDP Growth for each country

# %%
df.groupby('Entity')['gdp_growth'].min().sort_values()
# Out:
# Entity
# Libya                              -62.075920
# Iraq                               -36.658153
# Central African Republic           -36.391977
# Maldives                           -33.499902
# Liberia                            -30.145133
#                                       ...
# Saint Kitts and Nevis                     NaN
# Saint Lucia                               NaN
# Saint Vincent and the Grenadines          NaN
# Slovakia                                  NaN
# Yemen                                     NaN
# Name: gdp_growth, Length: 176, dtype: float64

# %% [markdown]
# Where does portugal stand in this?

# %%
df.groupby('Entity')['gdp_growth'].min()['Portugal']
# Out:
# -8.442456428

# %% [markdown]
# Also, sometimes it can be very useful to know the size of each group. For example:
# > How many records do we have per country

# %%
df.groupby('Entity').size().sort_values()
# Out:
# Entity
# French Guiana     1
# South Sudan       8
# Montenegro       14
# Serbia           14
# Afghanistan      21
#                  ..
# Georgia          21
# Germany          21
# Ghana            21
# Ethiopia         21
# Zimbabwe         21
# Length: 176, dtype: int64

# %% [markdown]
# ## Creating your own custom groupby operations with `.apply`
#
# Often, you will need to perform a custom operation on each group.
#
# For example:
# > Give me the countries with the highest gdp growth **by year**
#
# to solve this, we would need:
# 1. To group the data by year
# 2. In each group find the index of largest `gdp growth`
# 3. Use that index to find the `Country` of largest growth
# 4. repeat for all groups (though groupby handles that for us)
#
# This means we need data from two columns in our groupby operation: `gdp_growth` and `Entity`

# %%
# Give me the countries with the highest gdp growth **by year**

df.groupby('Year').apply(lambda subdf: subdf.loc[subdf['gdp_growth'].idxmax(),'Entity'])
# Out:
# <ipython-input-53-bef33402180d>:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Year').apply(lambda subdf: subdf.loc[subdf['gdp_growth'].idxmax(),'Entity'])
# Year
# 2000                Malta
# 2001    Equatorial Guinea
# 2002         Sierra Leone
# 2003               Kuwait
# 2004                 Iraq
# 2005           Azerbaijan
# 2006           Azerbaijan
# 2007           Azerbaijan
# 2008                Nauru
# 2009          Afghanistan
# 2010             Zimbabwe
# 2011             Mongolia
# 2012                Libya
# 2013                Nauru
# 2014                Nauru
# 2015              Ireland
# 2016                 Iraq
# 2017                Libya
# 2018                Libya
# 2019               Tuvalu
# 2020               Guyana
# dtype: object

# %% [markdown]
# pretty awesome right?

# %% [markdown]
# We can keep going and perform an even more complex query:
# > What is the country that had the highest gdp growth most times?

# %%
(df
 .groupby('Year')
 .apply(lambda subdf: subdf.loc[subdf['gdp_growth'].idxmax(),'Entity']) # This is what we had already
 .value_counts()
 .where(lambda x: x == x.max())
 .dropna()
 .index
 .tolist()
)
# Out:
# <ipython-input-54-c111d03e4649>:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda subdf: subdf.loc[subdf['gdp_growth'].idxmax(),'Entity']) # This is what we had already
# ['Azerbaijan', 'Nauru', 'Libya']

# %% [markdown]
# ![](https://github.com/samsung-ai-course/6-7-edition/blob/main/Data%20Wrangling/Data%20Wrangling%20-%20Pandas-Advanced/Data%20Analysis%20Advanced/media/cat.jpeg?raw=1)
