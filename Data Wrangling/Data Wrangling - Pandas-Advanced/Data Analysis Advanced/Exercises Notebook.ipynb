# %% [markdown]
# # options

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Exercise 0 - Read the data
#
# the file is under the folder data and is named `supermarket_sales_V2.csv`

# %%
url = 'https://raw.githubusercontent.com/samsung-ai-course/6-7-edition/refs/heads/main/Data%20Wrangling/Data%20Wrangling%20-%20Pandas-Advanced/Data%20Analysis%20Advanced/data/supermarket_sales_V2.csv'

df = pd.read_csv(url)
df.head(3)
df.shape
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Date   Time      Payment  \
# 0       Health and beauty       74.69         7  1/5/2019  13:08      Ewallet
# 1  Electronic accessories       15.28         5  3/8/2019  10:29         Cash
# 2      Home and lifestyle       46.33         7  3/3/2019  13:23  Credit card
#
#      cogs  Rating
# 0  522.83     9.1
# 1   76.40     9.6
# 2  324.31     7.4
# (1000, 13)

# %% [markdown]
# This data contains the necessary info to compute the remaining columns:

# %% [markdown]
# # Exercise 1 - Creating new columns

# %% [markdown]
# ## Exercise 1.1
#
# create a new column `Total (Before Taxes)` that represents the cost of the purchase before taxes obtained by multiplying the `quantity` by the `unit price`

# %%
df['Total (Before Taxes)'] = df['Quantity'] * df['Unit price']
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Date   Time      Payment  \
# 0       Health and beauty       74.69         7  1/5/2019  13:08      Ewallet
# 1  Electronic accessories       15.28         5  3/8/2019  10:29         Cash
# 2      Home and lifestyle       46.33         7  3/3/2019  13:23  Credit card
#
#      cogs  Rating  Total (Before Taxes)
# 0  522.83     9.1                522.83
# 1   76.40     9.6                 76.40
# 2  324.31     7.4                324.31

# %% [markdown]
# ## Exercise 1.2
#
# > Create a new column `Tax 7%` that represents a 7% of the `Total (Before Taxes)`

# %%
df['Tax 7%'] = df['Total (Before Taxes)'] * 0.07
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Date   Time      Payment  \
# 0       Health and beauty       74.69         7  1/5/2019  13:08      Ewallet
# 1  Electronic accessories       15.28         5  3/8/2019  10:29         Cash
# 2      Home and lifestyle       46.33         7  3/3/2019  13:23  Credit card
#
#      cogs  Rating  Total (Before Taxes)   Tax 7%
# 0  522.83     9.1                522.83  36.5981
# 1   76.40     9.6                 76.40   5.3480
# 2  324.31     7.4                324.31  22.7017

# %% [markdown]
# ## Exercise 1.3
# > Create a new column `Total` that represents the `Total (Before Taxes)` added with the `Tax 7%`

# %%
df['Total'] = df['Total (Before Taxes)'] + df['Tax 7%']
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Date   Time      Payment  \
# 0       Health and beauty       74.69         7  1/5/2019  13:08      Ewallet
# 1  Electronic accessories       15.28         5  3/8/2019  10:29         Cash
# 2      Home and lifestyle       46.33         7  3/3/2019  13:23  Credit card
#
#      cogs  Rating  Total (Before Taxes)   Tax 7%     Total
# 0  522.83     9.1                522.83  36.5981  559.4281
# 1   76.40     9.6                 76.40   5.3480   81.7480
# 2  324.31     7.4                324.31  22.7017  347.0117

# %% [markdown]
# ## Exercise 1.4
# > Create a new column `gross income` that represents the Total minus the cost of goods sold `cogs`

# %%
df['gross income'] = df['Total'] - df['cogs']
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Date   Time      Payment  \
# 0       Health and beauty       74.69         7  1/5/2019  13:08      Ewallet
# 1  Electronic accessories       15.28         5  3/8/2019  10:29         Cash
# 2      Home and lifestyle       46.33         7  3/3/2019  13:23  Credit card
#
#      cogs  Rating  Total (Before Taxes)   Tax 7%     Total  gross income
# 0  522.83     9.1                522.83  36.5981  559.4281       36.5981
# 1   76.40     9.6                 76.40   5.3480   81.7480        5.3480
# 2  324.31     7.4                324.31  22.7017  347.0117       22.7017

# %% [markdown]
# ## Exercise 1.5
# > Create a new column `gross margin percentage` that represents the `gross income` as a percentage of the `Total`

# %%
#ERRADO???

df['gross margin percentage'] = df['gross income'] / df['Total']
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Date   Time      Payment  \
# 0       Health and beauty       74.69         7  1/5/2019  13:08      Ewallet
# 1  Electronic accessories       15.28         5  3/8/2019  10:29         Cash
# 2      Home and lifestyle       46.33         7  3/3/2019  13:23  Credit card
#
#      cogs  Rating  Total (Before Taxes)   Tax 7%     Total  gross income  \
# 0  522.83     9.1                522.83  36.5981  559.4281       36.5981
# 1   76.40     9.6                 76.40   5.3480   81.7480        5.3480
# 2  324.31     7.4                324.31  22.7017  347.0117       22.7017
#
#    gross margin percentage
# 0                 0.065421
# 1                 0.065421
# 2                 0.065421

# %% [markdown]
# ## Exercise 1.6
# > Create a new column `hour` that is the hour of the day extracted from the column `Time`

# %%
df['hour'] = pd.to_datetime(df['Time'], format='%H:%M').dt.hour
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity      Date   Time      Payment  \
# 0       Health and beauty       74.69         7  1/5/2019  13:08      Ewallet
# 1  Electronic accessories       15.28         5  3/8/2019  10:29         Cash
# 2      Home and lifestyle       46.33         7  3/3/2019  13:23  Credit card
#
#      cogs  Rating  Total (Before Taxes)   Tax 7%     Total  gross income  \
# 0  522.83     9.1                522.83  36.5981  559.4281       36.5981
# 1   76.40     9.6                 76.40   5.3480   81.7480        5.3480
# 2  324.31     7.4                324.31  22.7017  347.0117       22.7017
#
#    gross margin percentage  hour
# 0                 0.065421    13
# 1                 0.065421    10
# 2                 0.065421    13

# %% [markdown]
# # Exercise 2 - Masking

# %% [markdown]
# ## Exercise 2.1
# > What is the median payment gross income the supermarket company has from men?

# %%
male_mask = df['Gender'] == 'Male'
df[male_mask]['gross income'].median()
# Out:
# 16.28200000000001

# %% [markdown]
# ## Exercise 2.2
# > How many purchases does the store in City `Mandalay` have?

# %%
n_purchases_mandalay = df[df['City'] == 'Mandalay'].shape[0]
n_purchases_mandalay
# Out:
# 332

# %% [markdown]
# ## Exercise 2.3
#
# > What is the average rating of `Member` costumers in the store `Yagon`

# %%
df[member_mask & yagon_mask]
# Out:
# Empty DataFrame
# Columns: [Invoice ID, Branch, City, Customer type, Gender, Product line, Unit price, Quantity, Date, Time, Payment, cogs, Rating, Total (Before Taxes), Tax 7%, Total, gross income, gross margin percentage, hour]
# Index: []

# %%
df['Customer type'].value_counts()
df['City'].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
member_mask = df['Customer type'] == 'Member'
yagon_mask = df['City'] == 'Yangon'

avg_rating_member_yagon = df[member_mask & yagon_mask]['Rating'].mean()
avg_rating_member_yagon
# Out:
# 6.99880239520958

# %% [markdown]
# ## Exercise 2.4
# what is the `Invoice ID` of the the most expensive purchase (`Total`) made in the morning (in other words: until, not including, 12 o´clock)

# %%
invoice_id = df[df['hour'] < 12]['Total'].idxmax()
invoice_id
# Out:
# 429

# %% [markdown]
# ## Exercise 2.5
# > What is the product line `Women` buy most often at night (between 19h and 24h, all inclusive)

# %%
women_mask = df['Gender'] == 'Female'
night_mask = (df['hour'] >= 19) & (df['hour'] <= 24)

product_line = df[women_mask & night_mask]['Product line'].value_counts().idxmax()
product_line
# Out:
# 'Food and beverages'

# %% [markdown]
# ## Exercise 2.6
# > How many purchases were made by women in both `Health and beauty` and `Home and Lifestyle` `Product lines`?

# %%
health_and_beauty_mask = df['Product line'] == 'Health and beauty'
home_and_lifestyle_mask = df['Product line'] == 'Home and lifestyle'

n_purchases = df[women_mask & (health_and_beauty_mask | home_and_lifestyle_mask)].shape[0]
n_purchases
# Out:
# 143

# %% [markdown]
# # Exercise 3 - Groupbys

# %% [markdown]
# ## Exercise 3.1
# > what is the average `Total` by gender?

# %%
df.groupby('Gender')['Total'].mean()
# Out:
# Gender
# Female    341.478433
# Male      316.709021
# Name: Total, dtype: float64

# %% [markdown]
# ## Exercise 3.1 b)
# > use a bar plot to show the previous result

# %%
df.groupby('Gender')['Total'].mean().plot(kind='bar')
plt.show()
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# ## Exercise 3.2
# > What is the average Rating by City?

# %%
df.groupby('City')['Rating'].mean()
# Out:
# City
# Mandalay     6.818072
# Naypyitaw    7.072866
# Yangon       7.027059
# Name: Rating, dtype: float64

# %% [markdown]
# ## Exercise 3.2 b)
# > use a bar plot to show the previous result

# %%
df.groupby('City')['Rating'].mean().plot(kind='bar')
plt.show()
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# ## Exercise 3.3
# > What is the `Product line` that sells most items (i.e. `Quantities`)

# %%
df.groupby('Product line')['Quantity'].sum().idxmax()
# Out:
# 'Electronic accessories'

# %% [markdown]
# ## Exercise 3.4
# > What is the activity of customers throughout the day?
#
# Compute the number of invoices at each hour of the day

# %%
df.groupby('hour')['Invoice ID'].count()
# Out:
# hour
# 10    101
# 11     90
# 12     89
# 13    103
# 14     83
# 15    102
# 16     77
# 17     74
# 18     93
# 19    113
# 20     75
# Name: Invoice ID, dtype: int64

# %% [markdown]
# ## Exercise 3.4 b)
# > use a bar plot to show the previous result

# %%
df.groupby('hour')['Invoice ID'].count().plot(kind='bar')
plt.show()
# Out:
# <Axes: xlabel='hour'>

# %% [markdown]
# ## Exercise 3.5
# > For each city, what is the `Invoice ID` of the highest `gross margin` sale?

# %%
df.groupby('City')['gross margin percentage'].idxmax()
# Out:
# City
# Mandalay     342
# Naypyitaw    723
# Yangon        37
# Name: gross margin percentage, dtype: int64

# %% [markdown]
# ## Exercise 3.6
#
# > For each customer type, what is the average gross margin on each Product line?
#
# Try passing a list of columns to the `.groupby` method, and compute the average `gross margin` of that groupby

# %%
df.groupby(['Customer type', 'Product line'])['gross margin percentage'].mean()
# Out:
# Customer type  Product line
# Member         Electronic accessories    0.065421
#                Fashion accessories       0.065421
#                Food and beverages        0.065421
#                Health and beauty         0.065421
#                Home and lifestyle        0.065421
#                Sports and travel         0.065421
# Normal         Electronic accessories    0.065421
#                Fashion accessories       0.065421
#                Food and beverages        0.065421
#                Health and beauty         0.065421
#                Home and lifestyle        0.065421
#                Sports and travel         0.065421
# Name: gross margin percentage, dtype: float64
